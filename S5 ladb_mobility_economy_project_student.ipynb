# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario general del revisor</b> <a class="tocSkip"></a><br />
# Status del proyecto: <b>Aprobado</b>
#
#
# </div>

# %% [markdown]
# ¡Hola!<br />
# Soy **Francisco Cortés**, estoy contento de revisar tu proyecto y ser parte de tu proceso de aprendizaje.
# A lo largo del texto, haré algunas observaciones sobre mejoras en el código y también haré comentarios sobre tus percepciones sobre el tema. Si existe algún error en el código, no te preocupes, estoy aquí para ayudarte a mejorarlo, en la primera iteración te lo señalaré para que tengas la oportunidad de corregirlo, pero si aún no encuentras una solución para esta tarea, te daré una pista más precisa en la próxima iteración y también algunos ejemplos prácticos. Estaré abierto a retroalimentación y discusiones sobre el tema.<br />
# Encontrarás mis comentarios a continuación - **por favor no los muevas, modifiques o borres**.
# Revisaré cuidadosamente tu código para comprobar que se han cumplido con los requisitos y te proporcionaré mis comentarios en cajas verdes, amarillas o rojas como esta:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si la ejecución fue perfecta succesfully.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si existe alguna recomendación para que tu código mejore.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si existen correcciones necesarias para cumplir con los requisitos. El trabajo no puede ser aceptado si hay alguna caja roja.
# </div>
#
# Puedes responderme de la siguiente manera:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# ## Introducción
#
# Como analista de datos, tu objetivo es **evaluar cómo la movilidad urbana se relaciona con la productividad económica en las principales ciudades latinoamericanas**.
# Para ello trabajarás con datos reales de TomTom Traffic Index y OECD Cities, que deberás limpiar, combinar y analizar para identificar en qué ciudades conviene invertir en infraestructura de transporte.

# %% [markdown]
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de ambos datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯Objetivo:**
# Importar las librerías necesarias, cargar los archivos CSV en DataFrames y realizar una revisión preliminar para entender su contenido.
#
# **Instrucciones:**
# - Importa las librerías `pandas`, `numpy`, `seaborn` y `matplotlib.pyplot`.
# - Carga los archivos usando `pd.read_csv()`:
#   - `'/datasets/tomtom_traffic.csv'`
#   - `/datasets/oecd_city_economy.csv` `.
# - Guarda los DataFrames en las variables `traffic` y `eco`.
# - Muestra las primeras 5 filas de cada DataFrame.

# %%
import pandas as pd   # importar librerías
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargar archivos
traffic = pd.read_csv("/datasets/tomtom_traffic.csv")
eco = pd.read_csv("/datasets/oecd_city_economy.csv")

# %%
traffic.head() # mostrar las primeras 5 filas de traffic
# Out:
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
# 3     ARE  abu-dhabi  2025-01-13 01:46:30.001        8.2               2.0
# 4     ARE  abu-dhabi  2025-01-13 00:01:30.000        1.1               1.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
# 3              4.1        2.0                  2.0  2025-01-06 01:46:30.000
# 4              0.2        1.0                  1.0  2025-01-06 00:01:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232
# 3                    7.723808                        7.899046  -0.175238
# 4                    8.336363                        8.604379  -0.268016

# %%
eco.head() # mostrar las primeras 5 filas de eco
# Out:
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
# 3  2023        brasilia     Brazil       15.999,00           8.3%
# 4  2023        salvador     Brazil        8.761,00          13.1%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60
# 3         13,50           4,70
# 4         16,00           3,90

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Explorar, limpiar y preparar los datos
#
# Antes de combinar los datasets, inspecciona su estructura, tipos de datos, columnas y valores faltantes.
# Anota las columnas que necesiten limpieza y luego estandariza los nombres de columnas.
#
# ### 2.1 Explorar la estructura y tipos de datos
#
# **🎯Objetivo:**
# Identificar columnas con tipos incorrectos, distribución y nulos, anotar las columnas que requieren conversión.
#
# **Instrucciones:**
#
# - Usa `.info()` para conocer la estructura de ambos DataFrames.
# - Muestra los primeros 3 renglones de cada DF.
# - Identifica si los detalles de cada DF estan bien o si requieren correcciones y escribe tus conclusiones en el bloque Markdown.
#   - ¿Hay columnas que requieren conversión?¿ Cuáles son? ¿Que tipo de dato ienen y cuál deberían de tener?
#   - ¿Hay datos ausentes en alguna columna?

# %%
# Examinar la estructura de traffic
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Country                         1004464 non-null  object
#  1   City                            1004464 non-null  object
#  2   UpdateTimeUTC                   1004464 non-null  object
#  3   JamsDelay                       1004464 non-null  float64
#  4   TrafficIndexLive                1004464 non-null  float64
#  5   JamsLengthInKms                 1004464 non-null  float64
#  6   JamsCount                       1004464 non-null  float64
#  7   TrafficIndexWeekAgo             1004464 non-null  float64
#  8   UpdateTimeUTCWeekAgo            1004464 non-null  object
#  9   TravelTimeLivePer10KmsMins      1004464 non-null  float64
#  10  TravelTimeHistoricPer10KmsMins  1004464 non-null  float64
#  11  MinsDelay                       1004464 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 92.0+ MB

# %%
import io

# 1. Capturar la salida completa
buffer = io.StringIO()
traffic.info(buf=buffer)

# 2. Obtener las líneas y seleccionar las primeras 8 (3 de encabezado + 2 de separadores/títulos + 3 de datos)
lineas = buffer.getvalue().splitlines()[:8]

# 3. Imprimir el bloque
print("\n".join(lineas))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Country                         1004464 non-null  object
#  1   City                            1004464 non-null  object
#  2   UpdateTimeUTC                   1004464 non-null  object

# %%
traffic.head(3)
# Out:
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232

# %%
traffic.describe
# Out:
# <bound method NDFrame.describe of         Country       City            UpdateTimeUTC  JamsDelay  \
# 0           ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7
# 1           ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4
# 2           ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8
# 3           ARE  abu-dhabi  2025-01-13 01:46:30.001        8.2
# 4           ARE  abu-dhabi  2025-01-13 00:01:30.000        1.1
# ...         ...        ...                      ...        ...
# 1004459     ZAF   pretoria  2024-10-01 12:31:30.000      195.1
# 1004460     ZAF   pretoria  2024-10-01 11:31:30.000       78.3
# 1004461     ZAF   pretoria  2024-10-01 10:01:30.000       85.0
# 1004462     ZAF   pretoria  2024-10-01 09:01:30.000       68.1
# 1004463     ZAF   pretoria  2024-10-01 08:46:30.000       67.7
#
#          TrafficIndexLive  JamsLengthInKms  JamsCount  TrafficIndexWeekAgo  \
# 0                    36.0            109.1      162.0                 30.0
# 1                    30.0            101.4      136.0                 27.0
# 2                     7.0             18.9       23.0                  6.0
# 3                     2.0              4.1        2.0                  2.0
# 4                     1.0              0.2        1.0                  1.0
# ...                   ...              ...        ...                  ...
# 1004459              27.0             27.2       66.0                 14.0
# 1004460              22.0              9.2       27.0                 15.0
# 1004461              21.0              9.7       29.0                 16.0
# 1004462              20.0              6.7       23.0                 15.0
# 1004463              20.0              6.6       22.0                 13.0
#
#             UpdateTimeUTCWeekAgo  TravelTimeLivePer10KmsMins  \
# 0        2025-01-06 04:01:30.000                   11.614767
# 1        2025-01-06 03:46:30.001                   11.003180
# 2        2025-01-06 02:46:30.000                    8.196278
# 3        2025-01-06 01:46:30.000                    7.723808
# 4        2025-01-06 00:01:30.000                    8.336363
# ...                          ...                         ...
# 1004459  2024-09-24 12:01:30.001                   14.930880
# 1004460  2024-09-24 11:01:30.000                   13.973285
# 1004461  2024-09-24 10:16:30.001                   13.690491
# 1004462  2024-09-24 09:46:30.000                   13.387203
# 1004463  2024-09-24 08:46:30.000                   13.311492
#
#          TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                             10.265330   1.349437
# 1                             10.031544   0.971635
# 2                              8.196510  -0.000232
# 3                              7.899046  -0.175238
# 4                              8.604379  -0.268016
# ...                                 ...        ...
# 1004459                       14.129215   0.801665
# 1004460                       13.630819   0.342466
# 1004461                       13.287302   0.403189
# 1004462                       12.983558   0.403646
# 1004463                       12.898624   0.412867
#
# [1004464 rows x 12 columns]>

# %%
traffic.dropna()
# Out:
#         Country       City            UpdateTimeUTC  JamsDelay  \
# 0           ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7
# 1           ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4
# 2           ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8
# 3           ARE  abu-dhabi  2025-01-13 01:46:30.001        8.2
# 4           ARE  abu-dhabi  2025-01-13 00:01:30.000        1.1
# ...         ...        ...                      ...        ...
# 1004459     ZAF   pretoria  2024-10-01 12:31:30.000      195.1
# 1004460     ZAF   pretoria  2024-10-01 11:31:30.000       78.3
# 1004461     ZAF   pretoria  2024-10-01 10:01:30.000       85.0
# 1004462     ZAF   pretoria  2024-10-01 09:01:30.000       68.1
# 1004463     ZAF   pretoria  2024-10-01 08:46:30.000       67.7
#
#          TrafficIndexLive  JamsLengthInKms  JamsCount  TrafficIndexWeekAgo  \
# 0                    36.0            109.1      162.0                 30.0
# 1                    30.0            101.4      136.0                 27.0
# 2                     7.0             18.9       23.0                  6.0
# 3                     2.0              4.1        2.0                  2.0
# 4                     1.0              0.2        1.0                  1.0
# ...                   ...              ...        ...                  ...
# 1004459              27.0             27.2       66.0                 14.0
# 1004460              22.0              9.2       27.0                 15.0
# 1004461              21.0              9.7       29.0                 16.0
# 1004462              20.0              6.7       23.0                 15.0
# 1004463              20.0              6.6       22.0                 13.0
#
#             UpdateTimeUTCWeekAgo  TravelTimeLivePer10KmsMins  \
# 0        2025-01-06 04:01:30.000                   11.614767
# 1        2025-01-06 03:46:30.001                   11.003180
# 2        2025-01-06 02:46:30.000                    8.196278
# 3        2025-01-06 01:46:30.000                    7.723808
# 4        2025-01-06 00:01:30.000                    8.336363
# ...                          ...                         ...
# 1004459  2024-09-24 12:01:30.001                   14.930880
# 1004460  2024-09-24 11:01:30.000                   13.973285
# 1004461  2024-09-24 10:16:30.001                   13.690491
# 1004462  2024-09-24 09:46:30.000                   13.387203
# 1004463  2024-09-24 08:46:30.000                   13.311492
#
#          TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                             10.265330   1.349437
# 1                             10.031544   0.971635
# 2                              8.196510  -0.000232
# 3                              7.899046  -0.175238
# 4                              8.604379  -0.268016
# ...                                 ...        ...
# 1004459                       14.129215   0.801665
# 1004460                       13.630819   0.342466
# 1004461                       13.287302   0.403189
# 1004462                       12.983558   0.403646
# 1004463                       12.898624   0.412867
#
# [1004464 rows x 12 columns]

# %% [markdown]
# En la estructura del DF traffic, se observa que:
# - Las columnas `UpdateTimeUTC` y `UpdateTimeUTCWeekAgo` son de tipo fecha
# - Las columnas `JamsDelay`,`JamsLengthInKms`,`TravelTimeLivePer10KmsMins`, `TravelTimeHistoricPer10KmsMins`, `MinsDelay` son de tipo float.
# - `MinsDelay`cuenta con numeros en negativo, que podría no generar conflicto al ser minutos de retraso y podrian llegar antes de lo esperado.
# - Las columnas `TrafficIndexLive`, `JamsCount`, `TrafficIndexWeekAgo`, `TrafficIndexLive`, `TrafficIndexLive`podrian trabajarse mejor como integer.
# - Revisando con dropna no se encontraron datos ausentes.

# %%
# Examinar la estructura de eco
eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             30 non-null     int64
#  1   City             30 non-null     object
#  2   Country          30 non-null     object
#  3   City GDP/capita  30 non-null     object
#  4   Unemployment %   30 non-null     object
#  5   PM2.5 (μg/m³)    30 non-null     object
#  6   Population (M)   30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB

# %%
import io

# 1. Capturar la salida completa
buffer = io.StringIO()
eco.info(buf=buffer)

# 2. Obtener las líneas y seleccionar las primeras 8 (3 de encabezado + 2 de separadores/títulos + 3 de datos)
lineas = buffer.getvalue().splitlines()[:8]

# 3. Imprimir el bloque
print("\n".join(lineas))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             30 non-null     int64
#  1   City             30 non-null     object
#  2   Country          30 non-null     object

# %%
eco.head(3)
# Out:
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60

# %%
eco.describe
# Out:
# <bound method NDFrame.describe of     Year            City    Country City GDP/capita Unemployment %  \
# 0   2023    buenos-aires  Argentina       15.782,00           6.2%
# 1   2023       sao-paulo     Brazil       14.475,00           9.1%
# 2   2023  rio-de-janeiro     Brazil       13.142,00           9.8%
# 3   2023        brasilia     Brazil       15.999,00           8.3%
# 4   2023        salvador     Brazil        8.761,00          13.1%
# 5   2023       fortaleza     Brazil          838,00          12.5%
# 6   2023  belo-horizonte     Brazil       10.951,00          10.1%
# 7   2023        curitiba     Brazil       12.189,00           8.8%
# 8   2023          recife     Brazil        9.047,00          11.8%
# 9   2023    porto-alegre     Brazil       11.618,00           9.2%
# 10  2023        santiago      Chile       22.176,00           8.5%
# 11  2023          bogota   Colombia       10.981,00          10.8%
# 12  2023     mexico-city     Mexico       20.426,00           3.5%
# 13  2023            lima       Peru       12.941,00           7.2%
# 14  2023      montevideo    Uruguay       25.408,00           8.9%
# 15  2024    buenos-aires  Argentina       18.117,00           7.2%
# 16  2024       sao-paulo     Brazil       14.703,00           8.5%
# 17  2024  rio-de-janeiro     Brazil       13.349,00           9.2%
# 18  2024        brasilia     Brazil       16.251,00           7.8%
# 19  2024        salvador     Brazil        8.899,00          12.4%
# 20  2024       fortaleza     Brazil        8.512,00          11.8%
# 21  2024  belo-horizonte     Brazil       11.124,00           9.5%
# 22  2024        curitiba     Brazil       12.381,00           8.2%
# 23  2024          recife     Brazil        9.189,00          11.2%
# 24  2024    porto-alegre     Brazil       11.801,00           8.7%
# 25  2024        santiago      Chile        2.277,00           7.8%
# 26  2024          bogota   Colombia       11.442,00            10%
# 27  2024     mexico-city     Mexico       21.111,00           3.2%
# 28  2024            lima       Peru       13.472,00           6.5%
# 29  2024      montevideo    Uruguay       26.176,00           8.4%
#
#    PM2.5 (μg/m³) Population (M)
# 0           15,2          15,30
# 1          29,50          22,50
# 2          19,10          13,60
# 3          13,50           4,70
# 4          16,00           3,90
# 5          15,40           4,20
# 6          17,50           6,00
# 7          14,20           3,60
# 8          16,50           4,10
# 9          14,90           4,30
# 10         22,80           7,00
# 11         18,40          11,20
# 12         23,70          22,00
# 13         20,50          11,10
# 14         11,80           1,80
# 15         14,50          15,40
# 16         28,00          22,60
# 17         18,40          13,70
# 18         12,80           4,80
# 19         15,20           3,90
# 20         14,60           4,20
# 21         16,80           6,10
# 22         13,50           3,70
# 23         15,80           4,10
# 24         14,20           4,30
# 25         21,30           7,10
# 26         17,60          11,30
# 27         22,30          22,10
# 28         19,70          11,20
# 29         11,20           1,80  >

# %%
eco.isna().count() #se reviso faltantes con el comando isna haciendo un recuento de los ausentes como otra opcion al dropna
# Out:
# Year               30
# City               30
# Country            30
# City GDP/capita    30
# Unemployment %     30
# PM2.5 (μg/m³)      30
# Population (M)     30
# dtype: int64

# %% [markdown]
# En la estructura del DF eco, se observa que:
# - Las columnas `City GDP/capita` puede trabajarse como integer o float y quitanto el punto inicial y cambiando la coma por punto.
# - Las columnas `Unemployment %`, `PM2.5 (μg/m³)`, `Population (M)`se deben ajustar a float y tambien cambiando las comas por puntos y ajustando el %
# - Las columnas `City`, `Country` son texto (string) y se puede ocupar como objeto o como String dependiendo de las necesidades.
# - - Revisando con dropna no se encontraron datos ausentes esta vez con la funcion isna.

# %% [markdown]
# ### 2.2 Renombrar columnas
#
# **🎯Objetivo:**
# Estandarizar los nombres de columnas para evitar errores y facilitar la unión de los datasets.
#
# **Instrucciones:**
#
# - Cambia los nombres de las columnas para que tengan el formato `snake_case`.
#     - `Country` → `country`
#     - `UpdateTimeUTC` → `update_time_utc`
# - Verifica que los cambios se hayan aplicado correctamente usando `.columns`.

# %%
# Estandarizar los nombres de las columnas de traffic
#tu código aquí
traffic = traffic.rename(columns={
'Country': 'country',
'City': 'city',
'UpdateTimeUTC': 'update_time_utc',
'JamsDelay': 'jams_delay',
'TrafficIndexLive': 'traffic_index_live',
'JamsLengthInKms': 'jams_length_kms',
'JamsCount': 'jams_count',
'TrafficIndexWeekAgo': 'traffic_index_week_ago',
'UpdateTimeUTCWeekAgo': 'update_time_utc_week_ago',
'TravelTimeLivePer10KmsMins': 'travel_time_live_per_10kms_mins',
'TravelTimeHistoricPer10KmsMins': 'travel_time_hist_per_10kms_mins',
'MinsDelay': 'mins_delay'})
# verificar cambios
traffic.columns
# Out:
# Index(['country', 'city', 'update_time_utc', 'jams_delay',
#        'traffic_index_live', 'jams_length_kms', 'jams_count',
#        'traffic_index_week_ago', 'update_time_utc_week_ago',
#        'travel_time_live_per_10kms_mins', 'travel_time_hist_per_10kms_mins',
#        'mins_delay'],
#       dtype='object')

# %%
# Estandarizar los nombres de las columnas de eco
#tu código aquí
eco = eco.rename(columns={
'Year': 'year',
'City': 'city', 
'Country': 'country', 
'City GDP/capita': 'city_gdp_capita', 
'Unemployment %': 'unemployment_pct',
'PM2.5 (μg/m³)': 'pm2.5', 
'Population (M)': 'population_m'})
# verificar cambios
eco.columns
# Out:
# Index(['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct',
#        'pm2.5', 'population_m'],
#       dtype='object')

# %% [markdown]
# ### 2.3 Corregir formatos numéricos y de fecha
#
# **🎯Objetivo:**
# Asegurar que las columnas de fechas y valores numéricos estén en formatos correctos para permitir análisis, cálculos y comparaciones precisas.
#
# **Instrucciones:**
#
# - Convierte las columnas de fecha de `traffic` a formato `datetime`. Haz el cambio a prueba de errores.
# - En el dataset `eco`, limpia los valores numéricos:
#     - En `city_gdp_capita`: elimina separadores de miles (`.`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `unemployment_pct`: elimina el símbolo de porcentaje (`%`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `population_m`: reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
# - Finalmente, crea una nueva columna llamada `population` multiplicando `population_m` por 1,000,000 para obtener la población total.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# para eliminar símbolos, puedes reemplazarlos por un texto vacío.

# %%
print("Columnas disponibles en traffic:")
print(traffic.columns.tolist())
# Out:
# Columnas disponibles en traffic:
# ['country', 'city', 'update_time_utc', 'jams_delay', 'traffic_index_live', 'jams_length_kms', 'jams_count', 'traffic_index_week_ago', 'update_time_utc_week_ago', 'travel_time_live_per_10kms_mins', 'travel_time_hist_per_10kms_mins', 'mins_delay']

# %%
# Convertir las columnas de traffic a tipo fecha con pd.to_datetime()
traffic['update_time_utc'] = pd.to_datetime(traffic['update_time_utc'], errors = "coerce", utc=True) #tu código aquí
traffic['update_time_utc_week_ago'] = pd.to_datetime(traffic['update_time_utc_week_ago'], errors = "coerce", utc=True) #tu código aquí

# verificar el cambio
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   country                          1004464 non-null  object
#  1   city                             1004464 non-null  object
#  2   update_time_utc                  1004464 non-null  datetime64[ns, UTC]
#  3   jams_delay                       1004464 non-null  float64
#  4   traffic_index_live               1004464 non-null  float64
#  5   jams_length_kms                  1004464 non-null  float64
#  6   jams_count                       1004464 non-null  float64
#  7   traffic_index_week_ago           1004464 non-null  float64
#  8   update_time_utc_week_ago         1004464 non-null  datetime64[ns, UTC]
#  9   travel_time_live_per_10kms_mins  1004464 non-null  float64
#  10  travel_time_hist_per_10kms_mins  1004464 non-null  float64
#  11  mins_delay                       1004464 non-null  float64
# dtypes: datetime64[ns, UTC](2), float64(8), object(2)
# memory usage: 92.0+ MB

# %%
# Diagnóstico completo del dataset económico
print("=== DIAGNÓSTICO DEL DATASET ECONÓMICO ===")
print(f"Forma: {eco.shape}")
print(f"Columnas ({len(eco.columns)}):")

for i, col in enumerate(eco.columns):
    print(f"{i+1:2d}. '{col}' ({eco[col].dtype})")
    
print("\nPrimeras 2 filas:")
print(eco.head(2))
# Out:
# === DIAGNÓSTICO DEL DATASET ECONÓMICO ===
# Forma: (30, 7)
# Columnas (7):
#  1. 'year' (int64)
#  2. 'city' (object)
#  3. 'country' (object)
#  4. 'city_gdp_capita' (object)
#  5. 'unemployment_pct' (object)
#  6. 'pm2.5' (object)
#  7. 'population_m' (object)
#
# Primeras 2 filas:
#    year          city    country city_gdp_capita unemployment_pct  pm2.5  \
# 0  2023  buenos-aires  Argentina       15.782,00             6.2%   15,2
# 1  2023     sao-paulo     Brazil       14.475,00             9.1%  29,50
#
#   population_m
# 0        15,30
# 1        22,50

# %%
# Limpia separadores y convierte columnas numéricas en eco
# eco['city_gdp_capita'] = ....astype(str).str.replace('.', '').str.replace(',', '.').astype(float)
# eco['unemployment_pct'] = ...
# eco['population_m'] = ...
eco['city_gdp_capita'] = (eco['city_gdp_capita']
.astype(str)
.str.replace('.', '',regex=False)
.str.replace(',', '.',regex=False)
.astype(float))
eco['pm2.5'] = (eco['pm2.5']
.astype(str)
.str.replace('.', '',regex=False)
.str.replace(',', '.',regex=False)
.astype(float))
eco['unemployment_pct'] = (eco['unemployment_pct']
.astype(str)
.str.replace('%', '',regex=False)
.str.replace(',', '.',regex=False)
.astype(float))
eco['population_m'] = (eco['population_m']
.astype(str)
.str.replace(',', '.',regex=False)
.astype(float))
# Calcula la población total en unidades absolutas (Multiplica * 1000000)
# eco['population'] = ...
eco['population'] = eco['population_m'] * 1_000_000
# verificar el cambio
eco.info()
eco.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              30 non-null     int64
#  1   city              30 non-null     object
#  2   country           30 non-null     object
#  3   city_gdp_capita   30 non-null     float64
#  4   unemployment_pct  30 non-null     float64
#  5   pm2.5             30 non-null     float64
#  6   population_m      30 non-null     float64
#  7   population        30 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 2.0+ KB
#    year            city    country  city_gdp_capita  unemployment_pct  pm2.5  \
# 0  2023    buenos-aires  Argentina          15782.0               6.2   15.2
# 1  2023       sao-paulo     Brazil          14475.0               9.1   29.5
# 2  2023  rio-de-janeiro     Brazil          13142.0               9.8   19.1
#
#    population_m  population
# 0          15.3  15300000.0
# 1          22.5  22500000.0
# 2          13.6  13600000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
#
# Los datos fueron revisados y modificados apropiadamente, ahora se puede empezar a trabajar con ellos comodamente
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Extraer año y filtrar
#
# Extraer el año permite filtrar la información y trabajar solo con el período más reciente y relevante.
#
# ### 3.1 Extraer columna año y filtrar 2024
#
# **🎯Objetivo**
# Identificar el año de cada registro y mantener solo los registros del 2024.
#
# **Intrucciones**
#
# - Como el DataFrame `traffic` no tiene una columna de año, utiliza el atributo `.dt.year` sobre su columna de fecha para crear una nueva columna llamada `year`.
# - Filtra las filas donde el año sea **2024**.
# - Utiliza `.copy()` para crear dos nuevos DataFrames (`traffic_2024` y `eco_2024`) para evitar modificar el dataset original.

# %%
# Extraer el año de las fechas en update_time_utc
# traffic['year'] = ...
# Verificar cambio
traffic['year'] = pd.to_datetime(traffic['update_time_utc']).dt.year
traffic.head(3)
# Out:
#   country       city                  update_time_utc  jams_delay  \
# 0     ARE  abu-dhabi 2025-01-13 04:01:30.001000+00:00       650.7
# 1     ARE  abu-dhabi        2025-01-13 03:46:00+00:00       540.4
# 2     ARE  abu-dhabi        2025-01-13 02:46:30+00:00        71.8
#
#    traffic_index_live  jams_length_kms  jams_count  traffic_index_week_ago  \
# 0                36.0            109.1       162.0                    30.0
# 1                30.0            101.4       136.0                    27.0
# 2                 7.0             18.9        23.0                     6.0
#
#           update_time_utc_week_ago  travel_time_live_per_10kms_mins  \
# 0        2025-01-06 04:01:30+00:00                        11.614767
# 1 2025-01-06 03:46:30.001000+00:00                        11.003180
# 2        2025-01-06 02:46:30+00:00                         8.196278
#
#    travel_time_hist_per_10kms_mins  mins_delay  year
# 0                        10.265330    1.349437  2025
# 1                        10.031544    0.971635  2025
# 2                         8.196510   -0.000232  2025

# %%
# Filtra los registros del año 2024
# traffic_2024 = traffic[...].copy()
# eco_2024 = ...
traffic_2024 = traffic[traffic['year'] == 2024].copy()
eco_2024 = eco[eco['year'] == 2024].copy()
# Revisar dataframes nuevos
display(traffic_2024.head(3))
display(eco_2024.head(3))
# Out:
#     country       city           update_time_utc  jams_delay  \
# 302     ARE  abu-dhabi 2024-12-31 23:01:30+00:00        12.9
# 303     ARE  abu-dhabi 2024-12-31 22:01:30+00:00       136.0
# 304     ARE  abu-dhabi 2024-12-31 21:16:30+00:00       455.2
#
#      traffic_index_live  jams_length_kms  jams_count  traffic_index_week_ago  \
# 302                 5.0              2.5         5.0                     2.0
# 303                21.0             20.6        32.0                     3.0
# 304                31.0             40.4        72.0                     4.0
#
#             update_time_utc_week_ago  travel_time_live_per_10kms_mins  \
# 302 2024-12-24 23:01:30.001000+00:00                         8.560399
# 303        2024-12-24 22:01:30+00:00                        10.355732
# 304        2024-12-24 21:01:30+00:00                        11.456878
#
#      travel_time_hist_per_10kms_mins  mins_delay  year
# 302                         8.519634    0.040765  2024
# 303                         9.049445    1.306286  2024
# 304                         9.305174    2.151704  2024
#     year            city    country  city_gdp_capita  unemployment_pct  pm2.5  \
# 15  2024    buenos-aires  Argentina          18117.0               7.2   14.5
# 16  2024       sao-paulo     Brazil          14703.0               8.5   28.0
# 17  2024  rio-de-janeiro     Brazil          13349.0               9.2   18.4
#
#     population_m  population
# 15          15.4  15400000.0
# 16          22.6  22600000.0
# 17          13.7  13700000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Buena manera de extraer el año y de filtrar los datos, ahora podemos trabajar con los datos requeridos
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Analizar y resumir datos de movilidad
#
# Como el dataset de tráfico contiene **múltiples registros por ciudad**. En esta parte, calcularás los promedios anuales por ciudad para simplificar el análisis y obtener una visión más clara de las tendencias generales.
#
# ### 4.1 Calcular promedios de tráfico por ciudad
#
# **🎯Objetivo:**
# Obtener una vista consolidada del tráfico promedio por ciudad y año, para analizar patrones generales sin depender de datos diarios.
#
# **Instrucciones**
#
# - Agrupa los datos por `city`, `country` y `year`.
# - Calcula el promedio **solo de las métricas de tráfico más relevantes**: como `jams_delay`, `traffic_index_live`, `jams_length_kms`, `jams_count`, `mins_delay`, y tiempos de viaje (`travel_time_live_per_10kms_mins` y `travel_time_hist_per_10kms_mins`).
# - Guarda el resultado como `traffic_city_year_2024`, mantén las columnas como variables (no índices).

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa ".agg()" para aplicar funciones de promedio. Al final, reinicia el índice para mantener las columnas de la agrupación como variables (no índices).

# %%
# Calcular los  promedios de trafico por ciudad, país y año

metrics_list = [
    'jams_delay', 
    'traffic_index_live', 
    'jams_length_kms', 
    'jams_count', 
    'mins_delay', 
    'travel_time_live_per_10kms_mins', 
    'travel_time_hist_per_10kms_mins'
]
traffic_city_year_2024 = (
    traffic_2024
    .groupby(['city', 'country', 'year'])[metrics_list]
    .agg('mean')
    .reset_index()
)

traffic_city_year_2024.head()
# Out:
#         city country  year  jams_delay  traffic_index_live  jams_length_kms  \
# 0   a-coruna     ESP  2024   17.935187           15.259774         2.198002
# 1     aachen     DEU  2024   26.732141           20.960314         3.892586
# 2     aarhus     DNK  2024   21.200616           16.575891         2.736736
# 3  abu-dhabi     ARE  2024  171.157315           13.902028        24.507380
# 4      adana     TUR  2024   83.864761           22.541040        11.827331
#
#    jams_count  mins_delay  travel_time_live_per_10kms_mins  \
# 0    4.934405    0.774172                        16.267977
# 1    6.601832    0.792968                        13.397861
# 2    6.109987    0.495276                        15.219292
# 3   47.268019    0.139764                         9.829092
# 4   23.754620    1.129749                        15.879694
#
#    travel_time_hist_per_10kms_mins
# 0                        15.493804
# 1                        12.604894
# 2                        14.724016
# 3                         9.689328
# 4                        14.749945

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Excelente!<br/>
#
# Has tomado las columnas correctas para hacer la agrupación del conjunto de datos, podemos ver ahora en las columnas los promedios de cada una de las ciudades
# </div>

# %% [markdown]
# ### 🧠 **Momento de reflexión**
#
# ¡Excelente trabajo hasta aquí!
#
# Ahora que ya tienes los promedios anuales por ciudad, es momento de **observarlos** con atención.
#
# Piensa:
#
# - ¿Cuál crees que tiene el mayor tiempo promedio de tráfico?
# - ¿Será una ciudad de **Europa**, de **Latinoamérica** o de **otra región** del mundo?
#
# Para descubrirlo, ejecuta esta línea de código:
#
# `traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)`
#
#
# 🔍 Observa qué ciudad aparece en los primeros lugares.
#
# ¿Te sorprenden los resultados? , ¿Coinciden con lo que imaginabas?

# %%
# tu código aquí
traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)
# Out:
#             city country  year   jams_delay  traffic_index_live  \
# 221  mexico-city     MEX  2024  2833.057892           34.218190
# 352        tokyo     JPN  2024  2152.574357           36.805059
# 246     new-york     USA  2024  2133.400000           28.210388
# 200       london     GBR  2024  2050.703662           29.230166
# 211       manila     PHL  2024  1741.493381           66.129402
# ..           ...     ...   ...          ...                 ...
# 111      dunedin     NZL  2024     4.651175           15.430809
# 363      uppsala     SWE  2024     4.194486           13.939168
# 123     fujairah     ARE  2024     4.025959           10.907719
# 12        almere     NLD  2024     3.633523            6.290478
# 117      el-paso     USA  2024     0.299024            2.340435
#
#      jams_length_kms  jams_count  mins_delay  travel_time_live_per_10kms_mins  \
# 221       389.239265  594.969392    1.855542                        21.809092
# 352       373.069734  518.809420    0.698152                        22.443778
# 246       398.227892  544.474902    1.396351                        18.505043
# 200       287.632868  471.795554    1.325160                        17.714139
# 211       246.858082  341.881205    2.469894                        27.134629
# ..               ...         ...         ...                              ...
# 111         0.712315    1.591384    0.633294                        16.226009
# 363         0.656368    1.349672    0.501802                        15.746717
# 123         0.731910    1.373006    0.194951                        11.662590
# 12          0.506362    1.064063   -0.017544                         9.467150
# 117         0.031114    0.078118   -0.250676                        10.690269
#
#      travel_time_hist_per_10kms_mins
# 221                        19.953550
# 352                        21.745626
# 246                        17.108691
# 200                        16.388979
# 211                        24.664734
# ..                               ...
# 111                        15.592715
# 363                        15.244916
# 123                        11.467639
# 12                          9.484694
# 117                        10.940945
#
# [387 rows x 10 columns]

# %% [markdown]
# La ciudad con el mayor tiempo promedio de tráfico es mexico_city

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Unir movilidad y economía
#
# Combinar datasets te permite analizar cómo se relacionan los indicadores económicos con los de movilidad.
#
# ### 5.1 Unir tráfico (tabla principal) con indicadores económicos
#
# **🎯Objetivo:**
# Combinar la información de tráfico y economía en un solo DataFrame para analizar cómo las condiciones económicas se relacionan con la movilidad urbana.
#
# **Instrucciones**
# - Selecciona solo las **columnas relevantes** de cada dataset (por ejemplo, variables clave de tráfico y de economía).
# - Usa `.copy()` al crear subconjuntos para evitar modificar el dataset original.
# - Une ambos DataFrames y define como **claves de unión** a `city` y `year`.
# - Mantén solo las ciudades y años presentes en ambos datasets.
# - Guarda el resultado en una nueva variable llamada `merged` y muestra las primeras 5 filas.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Aplica una unión de tipo "inner" para mantener las ciudades y años presentes en ambos datasets.

# %%
# Seleccionar columnas clave de tráfico y economía
left_cols = ['city','country','year','jams_delay','traffic_index_live',
             'jams_length_kms','jams_count','mins_delay',
             'travel_time_live_per_10kms_mins','travel_time_hist_per_10kms_mins']

right_cols = ['city','year','city_gdp_capita','unemployment_pct', 'pm2.5', 'population_m', 'population']

# Usar .copy() para crear los dos nuevos datasets reducidos
traffic_2024_small = traffic_city_year_2024[left_cols].copy()
eco_2024_small = eco_2024[right_cols].copy()

# Unir datasets
merged = pd.merge(
    traffic_2024_small,
    eco_2024_small,
    on=['city', 'year'],
    how='inner') # tu código aquí

# Mostrar las primeras 5 filas
# tu código aquí
merged.head(5)
# Out:
#              city country  year   jams_delay  traffic_index_live  \
# 0  belo-horizonte     BRA  2024   263.047879           19.428946
# 1          bogota     COL  2024  1141.552364           37.614273
# 2        brasilia     BRA  2024   101.576326           11.258220
# 3    buenos-aires     ARG  2024   571.089593           17.756012
# 4        curitiba     BRA  2024   183.469274           14.954545
#
#    jams_length_kms  jams_count  mins_delay  travel_time_live_per_10kms_mins  \
# 0        44.038129   68.805422    0.487228                        18.304538
# 1       140.893564  230.566550    1.699628                        24.992185
# 2        18.337133   27.280140    0.193442                        13.338658
# 3       100.287844  137.359860    0.416566                        17.907916
# 4        30.050044   46.898164    0.139965                        17.258700
#
#    travel_time_hist_per_10kms_mins  city_gdp_capita  unemployment_pct  pm2.5  \
# 0                        17.817311          11124.0               9.5   16.8
# 1                        23.292557          11442.0              10.0   17.6
# 2                        13.145216          16251.0               7.8   12.8
# 3                        17.491349          18117.0               7.2   14.5
# 4                        17.118736          12381.0               8.2   13.5
#
#    population_m  population
# 0           6.1   6100000.0
# 1          11.3  11300000.0
# 2           4.8   4800000.0
# 3          15.4  15400000.0
# 4           3.7   3700000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
#
# La union de los datos se hizo de una buena manera al tomar solo las columnas necesarias de cada uno de los conjuntos de datos
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Visualización y análisis de relaciones
#
# Ahora que tienes un dataset limpio y unificado, es momento de **visualizar patrones**.
# Los gráficos te ayudarán a entender cómo se relacionan las variables económicas con las de movilidad urbana.
#
# ### 6.1 Visualizar relaciones entre economía y tráfico
#
# **🎯Objetivo:**
# Analizar visualmente la distribución y la relación entre indicadores de tráfico y economía en 2024, para identificar posibles patrones o tendencias generales entre ambas variables.
#
# **Instrucciones**
# - Usa las librerías `seaborn` y `matplotlib.pyplot` para generar los gráficos.
# - Visualiza la distribución del **tráfico** (`jams_delay`) mediante:
#     - **Boxplot** → para observar la media, mediana y detectar valores atípicos.
# - Visualiza la distribución de la **economía** (`city_gdp_capita`) mediante:
#     - **Histograma** → para analizar la forma de la distribución y el valor promedio del PIB per cápita.
# - Finalmente, **compara ambas variables**, para observar si existe alguna relación entre ellas, haciendo un solo gráfico de barras donde aparezcan ambos indicadores.
# - Recuerda agregar título y etiquetas a los ejes de tus gráficos.
# - Observa y comenta los patrones, valores extremos o posibles relaciones que identifiques.

# %% [markdown]
# **Tip:** Dentro de los parentesis del boxplot, agrega `showmeans=True` para ver la media en el gráfico.

# %%
# Crear boxplot para observar el comportamiento de los minutos de congestion JamsDelay
# crea tu gráfico

# Paso 1: Calcular estadísticas
mean_value = merged['jams_delay'].mean()
median_value = merged['jams_delay'].median()

# Paso 2: Crear el gráfico
plt.figure(figsize=(8, 6))
sns.boxplot(
    data=merged, 
    y='jams_delay', 
    showmeans=True, 
    meanprops={"marker":"o", "markerfacecolor":"white", "markersize":8}
)

# Paso 3: Personalizar el gráfico
plt.title(f'Boxplot de JamsDelay (2024)\nPromedio: {mean_value:.2f} min | Mediana: {median_value:.2f} min')
plt.ylabel('Minutos de Retraso (Jams Delay)')
plt.xlabel('Promedio')

# Paso 4: Mostrar el gráfico

plt.show()

 #Paso 5: Mostrar estadísticas adicionales
print(f"Estadísticas de Jams Delay:")
print(f"Promedio: {mean_value:.2f} minutos")
print(f"Mediana: {median_value:.2f} minutos")
print(f"Desviación estándar: {merged['jams_delay'].std():.2f} minutos")
# Out:
# Estadísticas de Jams Delay:
# Promedio: 629.52 minutos
# Mediana: 263.05 minutos
# Desviación estándar: 783.06 minutos

# %%
# Crear histograma para ver la distribución de la economía (city_gdp_capita)

promedio_gdp = merged['city_gdp_capita'].mean()

sns.histplot(
    data=merged, 
    x='city_gdp_capita', 
    bins=20,            # Divide los datos en 20 rangos
    kde=True,           # Dibuja la curva de suavizado
    color='teal'        # Color de las barras
)
plt.axvline(promedio_gdp, color='red', linestyle='--', label=f'Promedio: {promedio_gdp:.2f}')
plt.title('Distribución del PIB per Cápita (2024)')
plt.xlabel('PIB per Cápita')
plt.ylabel('Cantidad de Ciudades')
plt.legend()  # Muestra la etiqueta del promedio

plt.show()

# %%
# Gráfico de barras para comparar jams_delay y city_gdp_capita por ciudad
#merged.plot( ... , y=['jams_delay', 'city_gdp_capita'])

merged_sorted = merged.sort_values(by='city_gdp_capita', ascending=False)

plt.figure(figsize=(16, 10))
merged_sorted.set_index('city')[['jams_delay', 'city_gdp_capita']].plot(
    kind='bar', 
        color=['skyblue', 'orange']
)
plt.title('Ranking de Economía (PIB) y Tráfico (Jams Delay) por Ciudad', fontsize=14)
plt.xlabel('Ciudad', fontsize=14)
plt.ylabel('Valor de los Indicadores PIB', fontsize=14)
plt.xticks(rotation=90)

plt.legend(['Retraso Tráfico (Jams Delay)', 'PIB per Cápita (GDP)'])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
#
# La visualización de los datos me parece correcta, podemos ver los distintos patrones en cada una de las ciudades lo cual es bastante útil para hacer hallazgos interesantes
# </div>

# %% [markdown]
# **Tip:** Antes del `plt.show()` agrega el código `plt.xticks(rotation=90)` para rotar las etiquetas del eje X en 90 grados.

# %% [markdown]
# ### 🧠 **Reflexiona**
# Excelente trabajo llegando a esta etapa del análisis. Antes de avanzar, revisa tus gráficos, tómate un momento para pensar:
#
# * ¿Las ciudades con mayor PIB per cápita también presentan más congestión?
#
# * ¿O sucede lo contrario, o no existe una relación clara?

# %% [markdown]
# Ciudad de Mexico es la que mas congestión presenta seguido de Sao Paulo
# No existe una relación clara ya que tenemos otras ciudades con mayor PIB
# tienen poco retraso como Montevideo, aunque se puede notar que las ciudades con mayor población presentan mayor congestión

# %% [markdown]
# ---
#
# ## 🧩Paso 7: Exportar y documentar resultados
#
# En esta etapa final consolidarás todo tu trabajo: guardarás el dataset limpio y crearás un resumen que documente los resultados del proyecto.
#
# ### 7.1 Guardar dataset final
#
# **🎯Objetivo:**
# Generar un CSV limpio, reproducible y con columnas relevantes para análisis posterior.
#
# **Instrucciones**
#
# - Exporta el DataFrame `merged` con el nombre: `ladb_mobility_economy_2024_clean.csv`
# - Usa `index=False` para no incluir el índice.

# %%
# Exporta el dataset final como CSV
merged.to_csv("ladb_mobility_economy_2024_clean.csv", index=False)

# %% [markdown]
# Para poder ver o descargar el archivo generado:
# En el menú lateral que esta a la izquierda, ve hasta la parte de abajo, a la sección de **Exportar dataset** para más información.

# %% [markdown]
# ---
#
# ## ✅ Entregables
#
# 1. **Notebook `.ipynb`** con todas las celdas (código + comentarios).
# 2. **CSV final**: `ladb_mobility_economy_2024_clean.csv`.
# 3. **Resumen ejecutivo breve** en Markdown (3–5 párrafos).

# %% [markdown]
# ---
#
# # 🧾 Resumen ejecutivo (plantilla)
#
# > Completa este resumen al finalizar el análisis. Mantén 3–5 párrafos cortos, claros y accionables.
#
# **Contexto & objetivo:**
# - Responde la pregunta central del análisis: ¿qué relación existe entre la movilidad urbana (congestión, tiempos de viaje) y la productividad económica (PIB per cápita)?
# - No existe una relación clara entre el PIB per capita con la movilidad, aunque si existe una tendencia con algunos paises como Uruguay que tienen una buena movilidad y productividad economica solo se cuena con la información de una ciudad. Y tenemos algunos casos "atipicos" como en Brasil, en Sao-Paulo hay poca movilidad pero un buen PIB, pero en otras ciudades con menos población notamos una movilidad moderada y un buen PIB.
# - Existe una relacion clara entre la longitud de los embotellamientos en kilometros con la población en ciudades importantes como Sao-Paulo, Ciudad de Mexico, Lima, entre otros.
# - Explica brevemente las variables clave utilizadas y su relevancia para la toma de decisiones.
#
# - Las variables clave ocupadas fueron "jams_length_kms", "jams_count", "population" y "city_gdp_capita"
#
# **Cobertura de datos:**
# - Especifica los años analizados, número de ciudades y países incluidos.
# - Se tomaron en cuenta los datos del 2024, tomando en cuenta 15 de las ciudades mas importantes de México y Centroamerica, como Argentina, Perú, Uruguay, Brasil, Colombia y Chile
#
# **Metodología (alto nivel):**
# - Describe los procesos principales: Se reviso que con los comandos info() describe, isna() junto con count(), dropna como otra opcion para eliminar y verificar datos nulos.
# - Se estandarizaron los nombres de las columnas con el formato o estilo "snake_eyes" y los campos de fecha se estandarizaron con pd.to_datetime y algunos valores se ajustaron a float cambiando errores en datos sustituyendo "," por "." y eliminando signo "%".
# - Explica la agregación por ciudad–año y el uso de una unión INNER para integrar tráfico y economía.
# - Se agrego el año tomando el atributo dt.year de la copia del dataset "traffic" para poder trabajar con un identificador unico en el "merged" generando una unión tipo inner para obtener solo los datos que coincidan en ambas tablas.
# - Menciona las validaciones visuales empleadas (distribuciones, outliers, tendencias generales).
# - Boxplot_ Promedio: 629.52 minutos y Desviación estándar: 783.06 minutos tenemos una gran variabilidad en la distribución entre los datos, algunos muy altos y otros muy bajos como podemos observar con Mexico, Chile y Uruguay, en donde contamos con pocos datos por ciudad.
# - Se nota una tendencia considerable entre la cantidad de poblacion de una ciudad y los retrasos por embotellamiento tanto en cantidad como en kilometros.
#
# **Hallazgos iniciales:**
# - Resume los patrones más importantes entre índices de tráfico y PIB per cápita.
# - Destaca anomalías u outliers que podrían requerir revisión adicional o un análisis más profundo.
# - Uruguay, Montevideo mejor desempeño trafico vs PIB, pero tenemos casos atipicos y algunos outliers con otras ciudades importantes como Ciudad de Mexico, Sao.Paulo y Bogota.
# - Algunos outliers a considerar son el bajo promedio de retrasos en Montevideo siendo de 50.2 puntos en comparación del resto de ciudades, tomando en cuenta el numero más alto registrado en Ciudad de Mexico que corresponde a 2833 puntos.
# - Seria pertinente revisar o obtener mas data sobre estas ciudades, ya que se puede percibir una tendencia a mayor retraso por traffico en ciudades bastante pobladas. Esto debe tomarse en cuenta para validar tambien los datos de Uruguay, Montevideo ya que cuenta con una poblacion relativamente baja de 1,800,000 en comparacion de Mexico y Sao-Paulo que cuentan con mas de 20,000,000 de población.
#
# **Recomendaciones**
#
# Aterriza los hallazgos en acciones: ciudades prioritarias, necesidad de validar fuentes, requerimiento de análisis adicionales, o propuestas de inversión.
#
# Las ciudades con un alto indice poblacional tiene un gran potencial. Se sugiere iniciar con ciudades como Brasilia, Sao-paulo, Río de Janeiro. Ya que los recursos y personal podria trabajar en el mismo pais sin tener que generar gastos extras en movilidad a otros paises
#
# Se sugierre analisis adicionales para revisar infraestuctura y viabilidad. Tomando en cuenta que existen otras ciudades con mucha población pero con grandes indices de trafico, lo cual puede ser atribuido por la infraestructura vial.
#
# Se recomienda generar analisis más profundos de otras ciudades en paises como Mexico, Argentina, Colombia y Perú, ya que actualmente solo contamos con informacion de una ciudad por Pais.
#
# - ¿Qué ciudad : Bogotá, Lima o Buenos Aires o alguna otra en particular, muestra la mayor correlación significativa entre altos niveles de congestión vehicular y bajos indicadores de productividad económica, sugiriendo ser una ciudad prioritaria para inversión en infraestructura de transporte?
# - Tanto Bogotá como Lima muestran una mayor correlacion entre los niveles de congestion vehicular en comparación a Buenos Aires es de casi el doble en retrasos por embotellamiento y en cantidad de embotellamientos. Lo cual podria ser un buen indicativo para revisar. Saber que esta haciendo bien Buenos Aires, si es su sistema de transporte colectivo, su infrastructura de calles y pavimentación. El indagar más en estos datos nos ayudará a entender donde y como podemos invertir mejor.

# %% [markdown]
# ## Comentario general del revisor
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Has realizado un muy buen trabajo al desarrollar este proyecto, las observaciones que has hecho a lo largo del mismo han servido para tomar acción en los pasos posteriores, terminando en resultados positivos.
#
# Los datos utilizados en este proyecto son bastante útiles e interesantes para hacer hallazgos interesantes, ya que son ciudades que conocemos y podemos asimilar de una mejor manera el contexto en el que situa el proyecto.
#
# Continúa con el buen trabajo y mucho éxito en el siguiente Sprint!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Aspectos positivos del proyecto</b> <a class="tocSkip"></a><br />
#
# - Las observaciones intermedias, así como las conclusiones finales me parecen buenas
# - Las graficas utilizadas me parecen del tipo correcto
# - El proyecto esta ordenado
#
# </div>
